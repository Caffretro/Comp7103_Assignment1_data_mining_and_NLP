# %%
import json
import pandas as pd

path = './data/fine_foods/fine_food_reviews.csv'

user_data = pd.read_csv(path)
user_data.shape
# Out:
# (568454, 10)

# %% [markdown]
# ### Based on user ratings in the 'overall' column, label reviews with Positive, Neutral, and Negative.

# %%
sampled_data = user_data.sample(n=5000)
# sampled_data.sort_index().head()
sampled_data = sampled_data.reset_index(drop=True)
sampled_data.head()
# Out:
#        Id   ProductId          UserId                 ProfileName  \
# 0  495946  B000G1766O  A3J171NBGIBYAW  D. Mansfield "Book Addict"
# 1  120328  B005K4Q37A  A3B9OUYMXYO6OX                  three cats
# 2  220149  B005BFJGJU  A11GL3QGJ3NM44                   R. Miller
# 3  294777  B005V9UG18   A8J808KNJK4K4                      Dianna
# 4   70491  B002E0S4UW  A3OFNY1N6I0R7A                   Fortunato
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     2                       3      3  1288569600
# 1                     1                       1      5  1323388800
# 2                     2                       3      1  1336348800
# 3                     0                       0      5  1346976000
# 4                     0                       0      5  1262044800
#
#                                     Summary  \
# 0                         Not what I needed
# 1  SPIKE this with some Irish cream liqueur
# 2                  Too little for the price
# 3                           Drink Every Day
# 4                         Wonderful product
#
#                                                 Text
# 0  I wanted to love. I think Amy's makes lots of ...
# 1  yes, this is flavored coffee already...but, it...
# 2  Sounded like a cute non-present but was way to...
# 3  I've been drinking the Chocolate Orgain for br...
# 4  My daughter loves this applesauce. We original...

# %%
sampled_data['SummartAndText'] = sampled_data['Summary'] + sampled_data['Text']
sampled_data.head()
# Out:
#        Id   ProductId          UserId                 ProfileName  \
# 0  495946  B000G1766O  A3J171NBGIBYAW  D. Mansfield "Book Addict"
# 1  120328  B005K4Q37A  A3B9OUYMXYO6OX                  three cats
# 2  220149  B005BFJGJU  A11GL3QGJ3NM44                   R. Miller
# 3  294777  B005V9UG18   A8J808KNJK4K4                      Dianna
# 4   70491  B002E0S4UW  A3OFNY1N6I0R7A                   Fortunato
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     2                       3      3  1288569600
# 1                     1                       1      5  1323388800
# 2                     2                       3      1  1336348800
# 3                     0                       0      5  1346976000
# 4                     0                       0      5  1262044800
#
#                                     Summary  \
# 0                         Not what I needed
# 1  SPIKE this with some Irish cream liqueur
# 2                  Too little for the price
# 3                           Drink Every Day
# 4                         Wonderful product
#
#                                                 Text  \
# 0  I wanted to love. I think Amy's makes lots of ...
# 1  yes, this is flavored coffee already...but, it...
# 2  Sounded like a cute non-present but was way to...
# 3  I've been drinking the Chocolate Orgain for br...
# 4  My daughter loves this applesauce. We original...
#
#                                       SummartAndText
# 0  Not what I neededI wanted to love. I think Amy...
# 1  SPIKE this with some Irish cream liqueuryes, t...
# 2  Too little for the priceSounded like a cute no...
# 3  Drink Every DayI've been drinking the Chocolat...
# 4  Wonderful productMy daughter loves this apples...

# %%
sampled_data.drop(inplace=True, columns=["ProfileName"])
sampled_data.to_csv('./data/fine_foods/0.02_sampled_fine_food_reviews.csv')
