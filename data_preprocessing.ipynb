# %%
import json
import pandas as pd

path = './data/fine_foods/fine_food_reviews.csv'

user_data = pd.read_csv(path)
user_data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %% [markdown]
# ### Based on user ratings in the 'overall' column, label reviews with Positive, Neutral, and Negative.

# %%
sampled_data = user_data.sample(n=100000)
# sampled_data.sort_index().head()
sampled_data = sampled_data.reset_index(drop=True)
sampled_data.head()
# Out:
#        Id   ProductId          UserId      ProfileName  HelpfulnessNumerator  \
# 0  151584  B000HTFEVE  A1BQEGGHCBCRRQ   Elaine Okupski                     0
# 1  177982  B00099ZGFG  A2S3Z54BI73QIK          G. Kerr                     3
# 2  538490  B000E4ARCS  A3BX21NIPUDXS5             John                     1
# 3  212032  B000CNB4LE  A1KZJ2Q8PKRIU6          Cobra23                     0
# 4  197792  B0078Y6CN0  A2AZU4JHTWYRY5  Practical Woman                     0
#
#    HelpfulnessDenominator  Score        Time  \
# 0                       0      5  1332806400
# 1                       3      5  1197072000
# 2                       1      5  1291593600
# 3                       0      1  1281312000
# 4                       0      4  1296950400
#
#                                   Summary  \
# 0  My second-favorite gluten-free granola
# 1             Great lean snack - ostrich!
# 2         Great product, excellent flavor
# 3                     What did they do???
# ...

# %%
sampled_data['SummartAndText'] = sampled_data['Summary'] + sampled_data['Text']
sampled_data.head()
# Out:
#        Id   ProductId          UserId      ProfileName  HelpfulnessNumerator  \
# 0  151584  B000HTFEVE  A1BQEGGHCBCRRQ   Elaine Okupski                     0
# 1  177982  B00099ZGFG  A2S3Z54BI73QIK          G. Kerr                     3
# 2  538490  B000E4ARCS  A3BX21NIPUDXS5             John                     1
# 3  212032  B000CNB4LE  A1KZJ2Q8PKRIU6          Cobra23                     0
# 4  197792  B0078Y6CN0  A2AZU4JHTWYRY5  Practical Woman                     0
#
#    HelpfulnessDenominator  Score        Time  \
# 0                       0      5  1332806400
# 1                       3      5  1197072000
# 2                       1      5  1291593600
# 3                       0      1  1281312000
# 4                       0      4  1296950400
#
#                                   Summary  \
# 0  My second-favorite gluten-free granola
# 1             Great lean snack - ostrich!
# 2         Great product, excellent flavor
# 3                     What did they do???
# ...

# %%
sampled_data.drop(inplace=True, columns=["ProfileName"])
sampled_data.to_csv('./data_amazon_review/sampled_fine_food_reviews.csv')
