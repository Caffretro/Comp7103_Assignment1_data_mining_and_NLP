# %%
import json
import pandas as pd

path = './data/fine_foods/fine_food_reviews.csv'

user_data = pd.read_csv(path)
user_data.shape
# Out:
# (568454, 10)

# %% [markdown]
# ### Based on user ratings in the 'overall' column, label reviews with Positive, Neutral, and Negative.

# %%
sampled_data = user_data.sample(n=5000)
# sampled_data.sort_index().head()
sampled_data = sampled_data.reset_index(drop=True)
sampled_data.head()
# Out:
#        Id   ProductId          UserId               ProfileName  \
# 0   98470  B004GW6O9E  A1KLXDCT2ZS8S1  Imda Booyah "booyah guy"
# 1  337957  B0014EOU4S  A2X4S50HN7RFVV              symbioticKid
# 2  413820  B0026KPDG8  A2IKA1EJF14J2T                    JDMTSX
# 3  561023  B0012BSMHY  A2VHBEFX94H61R                  Francine
# 4  499810  B000UBMO4Y   ARYSDAZNRXN6G                A. Crafton
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     0                       0      5  1306281600
# 1                     0                       0      3  1342051200
# 2                     0                       0      5  1298246400
# 3                     3                       3      4  1302480000
# 4                     4                       6      1  1263686400
#
#                                           Summary  \
# 0                          lara bars are the best
# 1                     Low sodium option is better
# 2  I hope they are as good for you as they taste!
# 3                         Stash Instant Green Tea
# 4                                  Make your own!
#
#                                                 Text
# 0  i have tried about a DOZEN different gluten fr...
# 1  Extremely good for vitamins. Tastes a bit like...
# 2  As far as the ingredients are concerned, the c...
# 3  I make a "jug" of this tea every morning and k...
# 4  This stuff is so bad, you may as well call it ...

# %%
sampled_data['SummartAndText'] = sampled_data['Summary'] + sampled_data['Text']
sampled_data.head()
# Out:
#        Id   ProductId          UserId               ProfileName  \
# 0   98470  B004GW6O9E  A1KLXDCT2ZS8S1  Imda Booyah "booyah guy"
# 1  337957  B0014EOU4S  A2X4S50HN7RFVV              symbioticKid
# 2  413820  B0026KPDG8  A2IKA1EJF14J2T                    JDMTSX
# 3  561023  B0012BSMHY  A2VHBEFX94H61R                  Francine
# 4  499810  B000UBMO4Y   ARYSDAZNRXN6G                A. Crafton
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     0                       0      5  1306281600
# 1                     0                       0      3  1342051200
# 2                     0                       0      5  1298246400
# 3                     3                       3      4  1302480000
# 4                     4                       6      1  1263686400
#
#                                           Summary  \
# 0                          lara bars are the best
# 1                     Low sodium option is better
# 2  I hope they are as good for you as they taste!
# 3                         Stash Instant Green Tea
# 4                                  Make your own!
#
#                                                 Text  \
# 0  i have tried about a DOZEN different gluten fr...
# 1  Extremely good for vitamins. Tastes a bit like...
# 2  As far as the ingredients are concerned, the c...
# 3  I make a "jug" of this tea every morning and k...
# 4  This stuff is so bad, you may as well call it ...
#
#                                       SummartAndText
# 0  lara bars are the besti have tried about a DOZ...
# 1  Low sodium option is betterExtremely good for ...
# 2  I hope they are as good for you as they taste!...
# 3  Stash Instant Green TeaI make a "jug" of this ...
# 4  Make your own!This stuff is so bad, you may as...

# %%
sampled_data.drop(inplace=True, columns=["ProfileName"])
sampled_data.to_csv('./data/fine_foods/0.01_sampled_fine_food_reviews.csv')
